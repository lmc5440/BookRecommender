# %%
# Imports
import pandas as pd
from surprise import Dataset
from surprise import Reader
from surprise import KNNBasic
from surprise.model_selection import train_test_split
from surprise import accuracy

# %%
# Load initial datasets
book_reviews_df = pd.read_csv("Resources/book_reviews.csv")
ratings_df = book_reviews_df[["User_id", "Id", "review/score"]].rename(columns={"User_id": "user_id", "Id": "book_id", "review/score": "rating"})
ratings_df
# Out:
#               user_id     book_id  rating
# 0       ADB0JID2XRFYR  0671551345     5.0
# 1                 NaN  0671551345     5.0
# 2                 NaN  0671551345     3.0
# 3      A1V0SFB3AXM8JK  0671551345     1.0
# 4                 NaN  0671551345     5.0
# ...               ...         ...     ...
# 17153  A3FQSMOE4M23KF  1591451876     5.0
# 17154  A1SY5CKBR26WOP  1591451876     5.0
# 17155  A15Y51EQ2MZKDT  1591451876     5.0
# 17156  A2VN986E5KR1NV  1591451876     5.0
# 17157  A2CWG50RM45QX8  1591451876     1.0
#
# [17158 rows x 3 columns]

# %%
# Check for missing values
book_reviews_df.isnull().sum()
# Out:
# Id                       0
# Title                    0
# Price                 6261
# User_id               2585
# profileName           2586
# review/helpfulness       0
# review/score             0
# review/time              0
# review/summary           3
# review/text              0
# dtype: int64

# %%
# Drop missing values
book_reviews_df = book_reviews_df.dropna()

# %%
#Define a Reader for Surprise based on your rating scale
# Surprise needs to know the rating scale.
reader = Reader(rating_scale=(0, 5))

# %%
# Load the data into Surprise Dataset format
data = Dataset.load_from_df(ratings_df, reader=reader)

# %%
trainset, testset = train_test_split(data, test_size=0.25, random_state=42) # 25% for testing
print(f"Trainset size: {trainset.n_ratings} ratings")
print(f"Testset size: {len(testset)} ratings")
# Out:
# Trainset size: 12868 ratings
# Testset size: 4290 ratings

# %%
# Configure KNNBasic for Item-Based CF
sim_options = {
    'name': 'cosine',  # Similarity metric: cosine similarity
    'user_based': False  # Item-based CF (as opposed to user-based)
}
algo = KNNBasic(sim_options=sim_options)

# Train the algorithm on the trainset
algo.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
user_id_to_predict = 'ADB0JID2XRFYR' # Replace with an actual user ID from your data (as string)
item_id_to_predict = '1591451876' # Replace with an actual item ID (book ID) from your data (as string)

prediction = algo.predict(user_id_to_predict, item_id_to_predict)
print(f"Predicted rating for user {user_id_to_predict} and item {item_id_to_predict}: {prediction.est}")
# Out:
# Predicted rating for user ADB0JID2XRFYR and item 1591451876: 4.250543985079267

# %%
def get_top_n_recommendations(algo, dataset, user_id, n=10):
    """
    Generates top N book recommendations for a given user using a trained Surprise algorithm.

    Args:
        algo: Trained Surprise recommendation algorithm.
        dataset: Surprise Dataset object (full training set is usually used for generating recommendations).
        user_id: User ID for whom to generate recommendations (as string).
        n: Number of recommendations to return (default is 10).

    Returns:
        A list of tuples, where each tuple is (item_id, predicted_rating),
        sorted by predicted_rating in descending order.
    """

    # 1. Get the list of items the user has *not* rated
    user_ratings = dataset.ur[dataset.to_inner_uid(user_id)] # Get user's ratings from training data
    rated_items = [iid for (iid, _) in user_ratings] # Extract item inner ids of rated items
    all_item_inner_ids = dataset.all_items() # Get all item inner ids in the dataset
    items_to_predict = [dataset.to_raw_iid(iid) # Convert inner to raw item ids
                         for iid in all_item_inner_ids if iid not in rated_items] # Get raw item ids of unrated items

    # 2. Predict ratings for unrated items
    predictions = [algo.predict(user_id, item_id) for item_id in items_to_predict]

    # 3. Sort predictions by estimated rating in descending order
    top_n_predictions = sorted(predictions, key=lambda pred: pred.est, reverse=True)[:n]

    # 4. Extract item IDs and predicted ratings
    top_n_recommendations = [(pred.iid, pred.est) for pred in top_n_predictions]

    return top_n_recommendations


# Example usage:
user_id_for_recommendation = 'ADB0JID2XRFYR' # Replace with a user ID from your data (as string)
top_recommendations = get_top_n_recommendations(algo, data.build_full_trainset(), user_id_for_recommendation, n=10)

print(f"Top 10 recommendations for user {user_id_for_recommendation}:")
for item_id, predicted_rating in top_recommendations:
    book_matches = book_reviews_df[book_reviews_df["Id"] == item_id]
    if not book_matches.empty:
        book_info = book_matches.iloc[0]
        print(f"Item ID: {item_id}, Book Title: {book_info['Title']}, Predicted Rating: {predicted_rating:.2f}")
    else:
        print(f"Item ID: {item_id}, Book Title: Not found in dataset, Predicted Rating: {predicted_rating:.2f}")
# Out:
# Top 10 recommendations for user ADB0JID2XRFYR:
# Item ID: 0813512964, Book Title: The Hidden Hand or, Capitola the Madcap (American Women Writers Series), Predicted Rating: 5.00
# Item ID: 1580627560, Book Title: Why Men Love Bitches: From Doormat to Dreamgirl - A Woman's Guide to Holding Her Own in a Relationship, Predicted Rating: 5.00
# Item ID: 0440228840, Book Title: Demon in My View (Den of Shadows), Predicted Rating: 5.00
# Item ID: 0590684892, Book Title: Not found in dataset, Predicted Rating: 5.00
# Item ID: 0553280589, Book Title: Not found in dataset, Predicted Rating: 5.00
# Item ID: 1563891700, Book Title: Not found in dataset, Predicted Rating: 5.00
# Item ID: 0440229405, Book Title: Shattered Mirror (Den of Shadows), Predicted Rating: 5.00
# Item ID: 0553480278, Book Title: Not found in dataset, Predicted Rating: 5.00
# Item ID: 0689865392, Book Title: Not found in dataset, Predicted Rating: 5.00
# ...

# %%
# Make predictions on the testset
test_predictions = algo.test(testset)

# Calculate RMSE
rmse = accuracy.rmse(test_predictions)
print(f"RMSE on test set: {rmse}")
# Out:
# RMSE: 1.1439
# RMSE on test set: 1.1438949974830377

# %%
def get_recommendations_for_new_user(new_user_ratings, original_data, algorithm):
    """
    Generates recommendations for a new user based on their provided ratings.

    Args:
        new_user_ratings (list of tuples): List of (item_id, rating) tuples for the new user.
        original_data (Dataset): The original Surprise Dataset.
        algorithm: Trained Surprise recommendation algorithm.

    Returns:
        list: Top N recommendations for the new user.
    """

    # 1. Create a new Reader and Dataset with the new user ratings added
    reader = Reader(rating_scale=(0, 5)) # Use the same rating scale as original data

    # Combine original ratings with new user ratings in a DataFrame format
    new_ratings_list = []
    for item_id, rating in new_user_ratings:
        new_ratings_list.append(('NewUser', item_id, rating)) # Use a fixed 'NewUser' ID

    # Convert new ratings to DataFrame
    new_user_ratings_df = pd.DataFrame(new_ratings_list, columns=['user_id', 'item_id', 'rating'])

    # Get original ratings as DataFrame
    original_ratings_df = pd.DataFrame([r[:3] for r in original_data.raw_ratings], columns=['user_id', 'item_id', 'rating'])

    # Concatenate original and new user ratings
    combined_ratings_df = pd.concat([original_ratings_df, new_user_ratings_df], ignore_index=True)

    # Load combined data into Surprise Dataset
    combined_data = Dataset.load_from_df(combined_ratings_df, reader=reader)

    # 2. Rebuild trainset on combined data and retrain the algorithm
    trainset_full_combined = combined_data.build_full_trainset()
    algorithm.fit(trainset_full_combined) # Retrain on the combined data

    # 3. Generate recommendations for 'NewUser'
    top_recommendations = get_top_n_recommendations(algorithm, trainset_full_combined, 'NewUser', n=10) # Recommend for 'NewUser'

    return top_recommendations


# --- User Interaction Part ---
while True:
    print("\nEnter book IDs and your ratings (0-5). Type 'done' when finished.")
    new_user_ratings_input = []
    while True:
        book_id_input = input("Enter Book ID (or 'done'): ")
        if book_id_input.lower() == 'done':
            break
        try:
            rating_input = float(input(f"Your rating for Book ID '{book_id_input}' (0-5): "))
            if 0 <= rating_input <= 5:
                new_user_ratings_input.append((book_id_input, rating_input))
            else:
                print("Invalid rating. Please enter a rating between 0 and 5.")
        except ValueError:
            print("Invalid rating. Please enter a number.")

    if not new_user_ratings_input: # If user didn't input any ratings, skip recommendation
        print("No book ratings provided. Exiting recommendation process.")
        continue # Go back to the outer loop to ask for another user or exit

    try:
        top_recommendations = get_recommendations_for_new_user(new_user_ratings_input, data, algo) # Use the function for new user

        print(f"\nTop 10 recommendations based on your ratings:")
        for item_id, predicted_rating in top_recommendations:
            book_matches = book_reviews_df[book_reviews_df["Id"] == item_id] # Use "id" here
            if not book_matches.empty:
                book_info = book_matches.iloc[0]
                print(f"  Item ID: {item_id}, Book Title: {book_info['Title']}, Predicted Rating: {predicted_rating:.2f}")
            else:
                print(f"  Item ID: {item_id}, Book Title: Not found in dataset, Predicted Rating: {predicted_rating:.2f}")

    except Exception as e:
        print(f"Error generating recommendations: {e}")

    if input("Do you want to get recommendations for another set of books? (yes/no): ").lower() != 'yes':
        break

print("Recommendation system closed.")
# Out:
# Enter book IDs and your ratings (0-5). Type 'done' when finished.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
#
# Top 10 recommendations based on your ratings:
#   Item ID: nan, Book Title: Not found in dataset, Predicted Rating: 4.25
#   Item ID: 1484482352, Book Title: Not found in dataset, Predicted Rating: 4.25
#   Item ID: 0369406370, Book Title: Not found in dataset, Predicted Rating: 4.25
# Recommendation system closed.
